# %%
import os
from geopy import geocoders
import geopandas
import geoplot
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cartopy
import cartopy.crs as ccrs
import seaborn as sns
import arcgis
from arcgis.gis import GIS
import pandas as pd
from arcgis.features import GeoAccessor, GeoSeriesAccessor
os.getcwd()
from pandas import ExcelWriter 
from geopy.geocoders import Nominatim
from time import sleep
geolocator = Nominatim(timeout=None)

import re
# Out:
# C:\Users\dsf3564\AppData\Local\conda\conda\envs\test\lib\site-packages\geopy\geocoders\osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning

# %%
shark = pd.read_csv('/Users/dsf3564/Documents/DSC 502/Shark_data/FinalShark_Data.csv',encoding='latin1')

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource
from bokeh.models.tools import HoverTool
from bokeh.palettes import Spectral5
from bokeh.transform import factor_cmap
from bokeh.palettes import Category20

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
group=shark.groupby('Activity_type').count()
group
#missing value doesn't have any data in the row so delete this row completely when showing the graph
# Out:
#                Unnamed: 0  Case Number  Date  Year  Type  Country  Area  \
# Activity_type
# bath                  191          191   191   191   191      189   176
# board                 207          207   207   207   207      202   196
# boat                   87           87    87    87    87       84    77
# canoe                  27           27    27    27    27       27    20
# diving                536          536   536   536   535      530   483
# fell                   88           88    88    88    88       86    65
# fish                  706          705   706   706   705      705   652
# float                  50           50    50    50    50       49    49
# kayak                  57           57    57    57    57       57    57
# other                1157         1157  1157  1157  1156     1143  1009
# row                    37           37    37    37    37       37    32
# ship                   61           61    61    61    61       55    46
# ski                    35           35    35    35    35       35    35
# snorkeling             95           95    95    95    95       95    90
# spear                 416          416   416   415   416      415   382
# surf                 1194         1194  1194  1194  1193     1193  1184
# swim                 1096         1096  1096  1095  1096     1089  1039
# tread                  38           38    38    38    38       38    37
# unknown                 5            5     5     5     5        5     5
# wading                169          169   169   169   169      168   165
# walking                26           26    26    26    26       26    26
# wash                   23           23    23    23    23       23    21
#
#                Location  Activity  Name      ...        Latitude  Longitude  \
# Activity_type                                ...
# bath                181       191   186      ...             109        109
# board               189       207   201      ...              99         99
# boat                 72        87    72      ...              29         29
# canoe                24        27    23      ...              14         14
# diving              453       536   519      ...             239        239
# fell                 61        88    88      ...              48         48
# fish                657       706   689      ...             346        346
# float                48        50    50      ...              28         28
# kayak                56        57    57      ...              28         28
# other               983       613  1062      ...             611        611
# row                  31        37    35      ...              16         16
# ship                 45        61    49      ...              23         23
# ski                  34        35    34      ...              21         21
# snorkeling           87        95    94      ...              36         36
# spear               386       416   410      ...             163        163
# surf               1180      1194  1184      ...             718        718
# swim               1024      1096  1078      ...             609        609
# tread                36        38    38      ...              23         23
# unknown               5         5     5      ...               2          2
# wading              164       169   169      ...             116        116
# walking              26        26    26      ...              14         14
# wash                 19        23    22      ...              11         11
#
#                Hour  time_cat  time2  size_ft  size_m  size  size_cat  \
# Activity_type
# bath             29        53     24       20      14    22        22
# board           119       135     16       53      45    70        70
# boat              6        10      4       12      13    14        14
# canoe             4         8      4        5       4     7         7
# diving          167       205     38      144     148   186       186
# fell              3        13     10        7       5     9         9
# fish            115       172     57      188     164   245       245
# float            27        34      7       14      10    15        15
# kayak            34        41      7       16      14    27        27
# other           217       284     67      191     145   229       228
# row               4         4      0        8       8    11        11
# ship             12        15      3        2       2     2         2
# ski              15        18      3       17      17    20        20
# snorkeling       54        63      9       24      36    43        43
# spear           167       193     26      170     165   210       210
# surf            798       885     90      398     321   515       515
# swim            447       541     95      203     169   236       236
# tread            30        33      3       13      16    17        17
# unknown           0         0      0        0       0     0         0
# wading           99       120     21       52      27    55        55
# walking          23        23      0        5       3     7         7
# wash              2         6      4        4       5     5         5
#
#                shark_species
# Activity_type
# bath                      12
# board                     68
# boat                      18
# canoe                      3
# diving                   237
# fell                       6
# fish                     245
# float                     10
# kayak                     38
# other                    232
# row                        8
# ship                       7
# ski                       14
# snorkeling                57
# spear                    227
# surf                     434
# swim                     265
# tread                     13
# unknown                    0
# wading                    36
# walking                    7
# wash                       4
#
# [22 rows x 32 columns]

# %%
#getting rid of missing value activity
group = group[group.index != 'nan']
group
# Out:
#                Unnamed: 0  Case Number  Date  Year  Type  Country  Area  \
# Activity_type
# bath                  191          191   191   191   191      189   176
# board                 207          207   207   207   207      202   196
# boat                   87           87    87    87    87       84    77
# canoe                  27           27    27    27    27       27    20
# diving                536          536   536   536   535      530   483
# fell                   88           88    88    88    88       86    65
# fish                  706          705   706   706   705      705   652
# float                  50           50    50    50    50       49    49
# kayak                  57           57    57    57    57       57    57
# other                1157         1157  1157  1157  1156     1143  1009
# row                    37           37    37    37    37       37    32
# ship                   61           61    61    61    61       55    46
# ski                    35           35    35    35    35       35    35
# snorkeling             95           95    95    95    95       95    90
# spear                 416          416   416   415   416      415   382
# surf                 1194         1194  1194  1194  1193     1193  1184
# swim                 1096         1096  1096  1095  1096     1089  1039
# tread                  38           38    38    38    38       38    37
# unknown                 5            5     5     5     5        5     5
# wading                169          169   169   169   169      168   165
# walking                26           26    26    26    26       26    26
# wash                   23           23    23    23    23       23    21
#
#                Location  Activity  Name      ...        Latitude  Longitude  \
# Activity_type                                ...
# bath                181       191   186      ...             109        109
# board               189       207   201      ...              99         99
# boat                 72        87    72      ...              29         29
# canoe                24        27    23      ...              14         14
# diving              453       536   519      ...             239        239
# fell                 61        88    88      ...              48         48
# fish                657       706   689      ...             346        346
# float                48        50    50      ...              28         28
# kayak                56        57    57      ...              28         28
# other               983       613  1062      ...             611        611
# row                  31        37    35      ...              16         16
# ship                 45        61    49      ...              23         23
# ski                  34        35    34      ...              21         21
# snorkeling           87        95    94      ...              36         36
# spear               386       416   410      ...             163        163
# surf               1180      1194  1184      ...             718        718
# swim               1024      1096  1078      ...             609        609
# tread                36        38    38      ...              23         23
# unknown               5         5     5      ...               2          2
# wading              164       169   169      ...             116        116
# walking              26        26    26      ...              14         14
# wash                 19        23    22      ...              11         11
#
#                Hour  time_cat  time2  size_ft  size_m  size  size_cat  \
# Activity_type
# bath             29        53     24       20      14    22        22
# board           119       135     16       53      45    70        70
# boat              6        10      4       12      13    14        14
# canoe             4         8      4        5       4     7         7
# diving          167       205     38      144     148   186       186
# fell              3        13     10        7       5     9         9
# fish            115       172     57      188     164   245       245
# float            27        34      7       14      10    15        15
# kayak            34        41      7       16      14    27        27
# other           217       284     67      191     145   229       228
# row               4         4      0        8       8    11        11
# ship             12        15      3        2       2     2         2
# ski              15        18      3       17      17    20        20
# snorkeling       54        63      9       24      36    43        43
# spear           167       193     26      170     165   210       210
# surf            798       885     90      398     321   515       515
# swim            447       541     95      203     169   236       236
# tread            30        33      3       13      16    17        17
# unknown           0         0      0        0       0     0         0
# wading           99       120     21       52      27    55        55
# walking          23        23      0        5       3     7         7
# wash              2         6      4        4       5     5         5
#
#                shark_species
# Activity_type
# bath                      12
# board                     68
# boat                      18
# canoe                      3
# diving                   237
# fell                       6
# fish                     245
# float                     10
# kayak                     38
# other                    232
# row                        8
# ship                       7
# ski                       14
# snorkeling                57
# spear                    227
# surf                     434
# swim                     265
# tread                     13
# unknown                    0
# wading                    36
# walking                    7
# wash                       4
#
# [22 rows x 32 columns]

# %%
shark[shark.Activity_type =='nan']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex, Age, Injury, Fatal (Y/N), Time, Species, Investigator or Source, pdf, href formula, href, original order, Full Location, Latitude, Longitude, Activity_type, Hour, time_cat, time2, size_ft, size_m, size, size_cat, shark_species]
# Index: []
#
# [0 rows x 33 columns]
