# %%
import pandas as pd

shark=pd.read_csv('../502 project/global-shark-attack.csv',sep=';')

# %%
shark.head()
# Out:
#     Case Number        Date    Year        Type        Country  \
# 0  2007.09.03.a  2007-09-03  2007.0  Unprovoked            USA
# 1  2007.09.30.a  2007-09-30  2007.0  Unprovoked  NEW CALEDONIA
# 2    2008.06.21  2008-06-21  2008.0     Boating            USA
# 3    2007.09.28  2007-09-28  2007.0  Unprovoked        BAHAMAS
# 4    2007.10.06  2007-10-06  2007.0  Unprovoked            USA
#
#                   Area                                           Location  \
# 0              Florida                    Fort Lauderdale, Broward County
# 1      Loyalty Islands                      Bay of Luengoni, Lifou Island
# 2           California                         West Cove, Catalina Island
# 3  Grand Bahama Island                                      Sweetings Cay
# 4              Florida  Playalinda Beach, Canaveral National Seashore,...
#
#        Activity                Name Sex      ...       Fatal (Y/N)  \
# 0      Swimming   Dominco Iaciofano   M      ...                 N
# ...

# %%
def count_entries(df, col_name):
    """Return a dictionary with counts of 
    occurrences as value for each key."""

    # Initialize an empty dictionary: langs_count
    entries_count={}
    
    # Extract column from DataFrame: col
    col=df[col_name]
    
    # Iterate over lang column in DataFrame
    for entry in col:

        # If the language is in langs_count, add 1
        if entry in entries_count.keys():
            entries_count[entry]+=1
        # Else add the language to langs_count, set the value to 1
        else:
            entries_count[entry]=1
    # Return the langs_count dictionary
    return(entries_count)


# Call count_entries(): result
result = count_entries(shark,'Location')

# Print the result
print(result)
# Out:
# {'Fort Lauderdale, Broward County': 5, 'Bay of Luengoni, Lifou Island': 1, 'West Cove, Catalina Island': 1, 'Sweetings Cay': 1, 'Playalinda Beach, Canaveral National Seashore, Brevard County': 5, 'San Cristobal Island': 1, 'Moonstone Beach, Humboldt County': 4, 'Hammocks Beach State Park, Bear Island, Onslow County': 1, 'Playas de Tijuana': 1, 'Aliwal Shoal': 2, 'Deep Sea World Aquarium': 1, 'New Smyrna Beach, Volusia County': 165, 'Guantanamo Bay': 1, 'Fingal Beach': 3, 'Off Tower Hill': 1, 'Umm Suqeim Beach, Dubai': 1, 'Alkantstrand': 1, 'Ponce, Volusia County': 1, 'Elliot Key': 2, 'Piedade, Recife': 4, 'Surf City, Topsail Island, Pender County': 2, nan: 548, 'Ponce Inlet, New Smyrna Beach, Volusia County': 12, 'Lahilahi Point, Oahu': 1, 'Luzon Strait': 1, 'North Haven': 1, 'Hutchinson Island': 1, 'North Myrtle Beach, Horry County': 5, 'Guantanamo': 1, 'Siletz River mouth, Lincoln County': 1, 'Boa Viagem Beach, Recife': 10, 'Kiawah Island, Charleston County': 3, "P' tit Paris, Sain
# ...

# %%
shark.Location.nunique()
# Out:
# 4057

# %%
shark.Location.value_counts()
# Out:
# New Smyrna Beach, Volusia County                                    165
# Daytona Beach, Volusia County                                        33
# Ponce Inlet, Volusia County                                          20
# Melbourne Beach, Brevard County                                      19
# Durban                                                               18
# Myrtle Beach, Horry County                                           17
# Isle of Palms, Charleston County                                     15
# Boa Viagem, Recife                                                   14
# Piedade                                                              12
# Cocoa Beach, Brevard County                                          12
# Cocoa Beach, Brevard  County                                         12
# Ponce Inlet, New Smyrna Beach, Volusia County                        12
# Ormond Beach, Volusia County                                         11
# ...

# %%
shark.Country.value_counts()
# Out:
# USA                               2226
# AUSTRALIA                         1334
# SOUTH AFRICA                       579
# PAPUA NEW GUINEA                   134
# NEW ZEALAND                        128
# BRAZIL                             111
# BAHAMAS                            109
# MEXICO                              89
# ITALY                               71
# FIJI                                62
# PHILIPPINES                         62
# REUNION                             60
# NEW CALEDONIA                       53
# CUBA                                46
# MOZAMBIQUE                          45
# SPAIN                               44
# INDIA                               40
# EGYPT                               40
# CROATIA                             34
# JAPAN                               34
# PANAMA                              32
# SOLOMON ISLANDS                     30
# IRAN                                29
# JAMAICA                             27
# ...

# %%
shark.Activity.value_counts()
# Out:
# Surfing                                                 973
# Swimming                                                915
# Fishing                                                 444
# Spearfishing                                            340
# Bathing                                                 165
# Wading                                                  149
# Diving                                                  130
# Standing                                                100
# Snorkeling                                               89
# Scuba diving                                             77
# Body boarding                                            62
# Body surfing                                             50
# Kayaking                                                 35
# Fell overboard                                           33
# Pearl diving                                             32
# Treading water                                           32
# ...

# %%
shark.Year.value_counts()
# Out:
# 2015.0    143
# 2017.0    135
# 2016.0    130
# 2011.0    128
# 2014.0    127
# 2013.0    122
# 2008.0    122
# 2009.0    120
# 2012.0    117
# 2007.0    112
# 2006.0    103
# 2005.0    103
# 2010.0    101
# 2000.0     97
# 1959.0     93
# 1960.0     93
# 2003.0     92
# 2001.0     92
# 2004.0     92
# 2002.0     88
# 1962.0     86
# 1961.0     78
# 1995.0     76
# 1999.0     66
# 1964.0     66
# 1998.0     65
# 1996.0     61
# 1963.0     61
# 1966.0     58
# 1997.0     57
#          ...
# 1764.0      1
# 1555.0      1
# 1753.0      1
# 1786.0      1
# 1779.0      1
# 1703.0      1
# 1822.0      1
# 1841.0      1
# 1723.0      1
# 1595.0      1
# 1802.0      1
# 1816.0      1
# 500.0       1
# 1767.0      1
# 1637.0      1
# 1797.0      1
# 1617.0      1
# 1807.0      1
# 1748.0      1
# 1788.0      1
# 1859.0      1
# 1749.0      1
# 1751.0      1
# 1801.0      1
# 1810.0      1
# 1784.0      1
# 1785.0      1
# 1755.0      1
# 1758.0      1
# 1834.0      1
# ...

# %%
shark.Species.value_counts()
# Out:
# White shark                                                                    163
# Shark involvement prior to death was not confirmed                             105
# Invalid                                                                        102
# Shark involvement not confirmed                                                 88
# Tiger shark                                                                     73
# Shark involvement prior to death unconfirmed                                    68
# Bull shark                                                                      52
# 4' shark                                                                        40
# 6' shark                                                                        40
# 1.8 m [6'] shark                                                                37
# Questionable incident                                                           35
# ...

# %%
shark.Fatal"("Y"/"N")".value_counts()
# Out:
#   File "<ipython-input-15-00ecf03446c6>", line 1
#     shark.Fatal"("Y"/"N")".value_counts()
#                  ^
# SyntaxError: invalid syntax
